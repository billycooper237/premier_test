# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data = pd.read_csv("C:\\Users\\GENERAL STORES\Desktop\\laboratoire\\archive\\breast-cancer.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = data.copy()
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
label = LabelEncoder()
df['diagnosis'] = label.fit_transform(df['diagnosis'])
df['diagnosis']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
X = df.drop('diagnosis',axis=1)
y = df['diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (455, 31)
# (455,)
# (114, 31)
# (114,)

# %%
from sklearn.metrics import f1_score,confusion_matrix ,classification_report
from sklearn.model_selection import learning_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PolynomialFeatures,OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
preprocessor = make_pipeline(PolynomialFeatures(2,include_bias=False),SelectKBest(f_classif,k=10))

# %%
#LinearRegression = make_pipeline(preprocessor,StandardScaler(),LinearRegression())
SVC = make_pipeline(preprocessor,StandardScaler(),SVC())
DecisionTreeClassifier =make_pipeline(preprocessor,StandardScaler(),DecisionTreeClassifier())
RandomForestClassifier = make_pipeline(preprocessor,StandardScaler(),RandomForestClassifier())

# %%
models ={
    #'LinearRegression': LinearRegression,
    ' SVC': SVC,
    ' DecisionTreeClassifier': DecisionTreeClassifier,
    'RandomForestClassifier':RandomForestClassifier,
}

# %%
def evaluation(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test, y_pred))
    
    N,train_score,val_score = learning_curve(model, X_train , y_train,
                                            cv=4, scoring='f1',
                                            train_sizes = np.linspace(0.1,1,10))
    plt.figure(figsize=(12,8))
    plt.plot(N, train_score.mean(axis=1),label='train score')
    plt.plot(N, val_score.mean(axis=1),label='validation score')
    plt.legend()

# %%
for nom,model in models.items():
    print(nom)
    evaluation(model)
# Out:
#  SVC
# [[67  0]
#  [ 3 44]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        67
#            1       1.00      0.94      0.97        47
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
#  DecisionTreeClassifier
# [[65  2]
#  [ 5 42]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        67
#            1       0.95      0.89      0.92        47
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.94       114
# weighted avg       0.94      0.94      0.94       114
#
# RandomForestClassifier
# [[67  0]
#  [ 3 44]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        67
#            1       1.00      0.94      0.97        47
#
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
SVC
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('polynomialfeatures',
#                                   PolynomialFeatures(include_bias=False)),
#                                  ('selectkbest', SelectKBest())])),
#                 ('standardscaler', StandardScaler()), ('svc', SVC())])
